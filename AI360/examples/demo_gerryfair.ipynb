# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import sys
sys.path.append("../")
from aif360.algorithms.inprocessing import GerryFairClassifier
from aif360.algorithms.inprocessing.gerryfair.clean import array_to_tuple
from aif360.algorithms.inprocessing.gerryfair.auditor import Auditor
from aif360.algorithms.preprocessing.optim_preproc_helpers.data_preproc_functions import load_preproc_data_adult
from sklearn import svm
from sklearn import tree
from sklearn.kernel_ridge import KernelRidge
from sklearn import linear_model
from aif360.metrics import BinaryLabelDatasetMetric
from IPython.display import Image
import pickle
import matplotlib.pyplot as plt

# load data set
# data_set = load_preproc_data_adult(sub_samp=1000, balance=True)
data_set = load_preproc_data_adult()
max_iterations = 500
# Out:
# 2022-11-16 22:35:06.636993: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# **instantiate, fit, and predict**
#
#
# We first demonstrate how to instantiate a `GerryFairClassifier`, `train` it with respect to rich subgroup fairness, and `predict` the label of a new example. We remark that when we set the `print_flag = True` at each iteration of the algorithm we print the error, fairness violation, and violated group size of most recent model. The error is the classification error of the classifier. At each round the Learner tries to find a classifier that minimizes the classification error plus a weighted sum of the fairness disparities on all the groups that the Auditor has found up until that point. By contrast the Auditor tries to find the group at each round with the greatest rich subgroup disparity with respect to the Learner's model. We define `violated group size` as the size (as a fraction of the dataset size) of this group, and the `fairness violation` as the `violated group size` times the difference in the statistical rate (FP or FN rate) on the group vs. the whole population.
#
# In the example below we set `max_iterations=500` which is an order of magnitude less than the time to convergence observed in [the rich subgroup fairness empirical paper](https://arxiv.org/abs/1808.08166), but advise that this can be highly dataset dependent. Our target $\gamma$-disparity is $\gamma = .005$, our statistical rate is false positive rate or `FP`, and our cost-sensitive classification oracle is linear regression (more on that below).

# %%
C = 100
print_flag = True
gamma = .005


fair_model = GerryFairClassifier(C=C, printflag=print_flag, gamma=gamma, fairness_def='FP',
             max_iters=max_iterations, heatmapflag=False)

# fit method
fair_model.fit(data_set, early_termination=True)

# predict method. If threshold in (0, 1) produces binary predictions

dataset_yhat = fair_model.predict(data_set, threshold=False)
# Out:
# iteration: 1, error: 0.19612218991851277, fairness violation: 0.01816858582022458, violated group size: 0.2952991277998444
# iteration: 2, error: 0.21770197780598666, fairness violation: 0.00908429291011229, violated group size: 0.2952991277998444
# iteration: 3, error: 0.22489524043514458, fairness violation: 0.006056195273408195, violated group size: 0.46541910650669505
# iteration: 4, error: 0.2284918717497236, fairness violation: 0.004542146455056145, violated group size: 0.2952991277998444
# iteration: 5, error: 0.23064985053847098, fairness violation: 0.0036337171640449173, violated group size: 0.2952991277998444
# iteration: 6, error: 0.2320885030643026, fairness violation: 0.0030280976367040966, violated group size: 0.2952991277998444
# iteration: 7, error: 0.23311611201132512, fairness violation: 0.002595512260032084, violated group size: 0.2952991277998444
# iteration: 8, error: 0.23388681872159206, fairness violation: 0.0022710732275280734, violated group size: 0.2952991277998444
# iteration: 9, error: 0.2344862572740219, fairness violation: 0.0020187317578027318, violated group size: 0.2952991277998444
# iteration: 10, error: 0.2349658081159658, fairness violation: 0.0018168585820224586, violated group size: 0.2952991277998444
# iteration: 11, error: 0.23535816789573805, fairness violation: 0.0016516896200204168, violated group size: 0.46541910650669505
# iteration: 12, error: 0.23568513437888153, fairness violation: 0.0015140488183520483, violated group size: 0.2952991277998444
# iteration: 13, error: 0.23596179832615688, fairness violation: 0.0013975835246326604, violated group size: 0.2952991277998444
# iteration: 14, error: 0.23619893885239288, fairness violation: 0.001297756130016042, violated group size: 0.2952991277998444
# iteration: 15, error: 0.23640446064179738, fairness violation: 0.0012112390546816392, violated group size: 0.2952991277998444
# iteration: 16, error: 0.2365842922075263, fairness violation: 0.0011355366137640367, violated group size: 0.2952991277998444
# iteration: 17, error: 0.23674296711846363, fairness violation: 0.0010687403423661525, violated group size: 0.2952991277998444
# iteration: 18, error: 0.23688401148374122, fairness violation: 0.001009365878901366, violated group size: 0.2952991277998444
# iteration: 19, error: 0.23701020907372647, fairness violation: 0.0009562413589591889, violated group size: 0.2952991277998444
# iteration: 20, error: 0.23712378690471317, fairness violation: 0.0009084292910112294, violated group size: 0.2952991277998444
# iteration: 21, error: 0.23722654779941546, fairness violation: 0.0008651707533440283, violated group size: 0.46541910650669505
# iteration: 22, error: 0.23731996679459932, fairness violation: 0.0008258448100102086, violated group size: 0.2952991277998444
# iteration: 23, error: 0.2374052623988976, fairness violation: 0.0007899385139228085, violated group size: 0.46541910650669505
# iteration: 24, error: 0.23748345003617108, fairness violation: 0.0007570244091760246, violated group size: 0.46541910650669505
# iteration: 25, error: 0.23755538266246265, fairness violation: 0.0007267434328089835, violated group size: 0.2952991277998444
# iteration: 26, error: 0.23762178200980874, fairness violation: 0.0006987917623163302, violated group size: 0.2952991277998444
# iteration: 27, error: 0.237683262886981, fairness violation: 0.0006729105859342439, violated group size: 0.46541910650669505
# iteration: 28, error: 0.2377403522729267, fairness violation: 0.000648878065008021, violated group size: 0.2952991277998444
# iteration: 29, error: 0.23779350445984168, fairness violation: 0.0006265029593180892, violated group size: 0.2952991277998444
# iteration: 30, error: 0.23784311316762896, fairness violation: 0.0006056195273408196, violated group size: 0.46541910650669505
# iteration: 31, error: 0.2378895213136235, fairness violation: 0.0005860834135556317, violated group size: 0.2952991277998444
# iteration: 32, error: 0.23793302895049342, fairness violation: 0.0005677683068820183, violated group size: 0.2952991277998444
# iteration: 33, error: 0.23797389976088637, fairness violation: 0.0005505632066734724, violated group size: 0.2952991277998444
# iteration: 34, error: 0.23801236640596207, fairness violation: 0.000534370171183076, violated group size: 0.2952991277998444
# iteration: 35, error: 0.23804863495703346, fairness violation: 0.0005191024520064167, violated group size: 0.2952991277998444
# iteration: 36, error: 0.2380828885886009, fairness violation: 0.0005046829394506829, violated group size: 0.2952991277998444
# iteration: 37, error: 0.238115290672516, fairness violation: 0.0004910428600060701, violated group size: 0.2952991277998444
# iteration: 38, error: 0.2381459873835935, fairness violation: 0.00047812067947959445, violated group size: 0.2952991277998444
# iteration: 39, error: 0.23817510990435933, fairness violation: 0.00046586117487755355, violated group size: 0.2952991277998444
# iteration: 40, error: 0.23820277629908684, fairness violation: 0.0004542146455056147, violated group size: 0.2952991277998444
# iteration: 41, error: 0.23822909311358376, fairness violation: 0.0004431362395176728, violated group size: 0.2952991277998444
# iteration: 42, error: 0.238254156746438, fairness violation: 0.00043258537667201414, violated group size: 0.46541910650669505
# iteration: 43, error: 0.2382780546289269, fairness violation: 0.00042252525163312984, violated group size: 0.2952991277998444
# iteration: 44, error: 0.23830086624402994, fairness violation: 0.0004129224050051042, violated group size: 0.46541910650669505
# iteration: 45, error: 0.2383226640095728, fairness violation: 0.0004037463515605464, violated group size: 0.2952991277998444
# iteration: 46, error: 0.23834351404617907, fairness violation: 0.00039496925696140415, violated group size: 0.46541910650669505
# iteration: 47, error: 0.23836347684718506, fairness violation: 0.0003865656557494592, violated group size: 0.2952991277998444
# iteration: 48, error: 0.23838260786481577, fairness violation: 0.00037851220458801207, violated group size: 0.2952991277998444
# iteration: 49, error: 0.23840095802458405, fairness violation: 0.0003707874657188691, violated group size: 0.2952991277998444
# iteration: 50, error: 0.23841857417796158, fairness violation: 0.00036337171640449164, violated group size: 0.2952991277998444
# iteration: 51, error: 0.23843549950179488, fairness violation: 0.0003562467807887173, violated group size: 0.2952991277998444
# iteration: 52, error: 0.2384517738516346, fairness violation: 0.000349395881158165, violated group size: 0.2952991277998444
# iteration: 53, error: 0.2384674340750653, fairness violation: 0.0003428035060419733, violated group size: 0.2952991277998444
# iteration: 54, error: 0.23848251429022074, fairness violation: 0.00033645529296712185, violated group size: 0.2952991277998444
# iteration: 55, error: 0.2384970461339161, fairness violation: 0.00033033792400408336, violated group size: 0.46541910650669505
# iteration: 56, error: 0.23851105898319358, fairness violation: 0.0003244390325040104, violated group size: 0.2952991277998444
# iteration: 57, error: 0.2385245801535492, fairness violation: 0.0003187471196530629, violated group size: 0.46541910650669505
# iteration: 58, error: 0.2385376350766511, fairness violation: 0.00031325147965904465, violated group size: 0.46541910650669505
# iteration: 59, error: 0.23855024745998687, fairness violation: 0.0003079421325461794, violated group size: 0.46541910650669505
# iteration: 60, error: 0.23856243943054473, fairness violation: 0.00030280976367040975, violated group size: 0.2952991277998444
# iteration: 61, error: 0.23857423166436303, fairness violation: 0.00029784566918400967, violated group size: 0.46541910650669505
# iteration: 62, error: 0.23858564350354203, fairness violation: 0.0002930417067778159, violated group size: 0.46541910650669505
# iteration: 63, error: 0.23859669306211215, fairness violation: 0.00028839025111467595, violated group size: 0.46541910650669505
# iteration: 64, error: 0.238607397321977, fairness violation: 0.00028388415344100907, violated group size: 0.2952991277998444
# iteration: 65, error: 0.23861777221999983, fairness violation: 0.00027951670492653213, violated group size: 0.46541910650669505
# iteration: 66, error: 0.23862783272717344, fairness violation: 0.00027528160333673614, violated group size: 0.2952991277998444
# iteration: 67, error: 0.23863759292070014, fairness violation: 0.0002711729226899191, violated group size: 0.2952991277998444
# iteration: 68, error: 0.2386470660497113, fairness violation: 0.000267185085591538, violated group size: 0.46541910650669505
# iteration: 69, error: 0.2386562645952729, fairness violation: 0.00026331283797426927, violated group size: 0.2952991277998444
# iteration: 70, error: 0.23866520032524705, fairness violation: 0.0002595512260032084, violated group size: 0.46541910650669505
# iteration: 71, error: 0.2386738843445176, fairness violation: 0.00025589557493274065, violated group size: 0.2952991277998444
# iteration: 72, error: 0.23868232714103071, fairness violation: 0.00025234146972534147, violated group size: 0.2952991277998444
# iteration: 73, error: 0.2386905386280503, fairness violation: 0.0002488847372633505, violated group size: 0.2952991277998444
# iteration: 74, error: 0.23869852818298828, fairness violation: 0.0002455214300030349, violated group size: 0.2952991277998444
# iteration: 75, error: 0.23870630468312792, fairness violation: 0.0002422478109363278, violated group size: 0.2952991277998444
# iteration: 76, error: 0.23871387653852702, fairness violation: 0.0002390603397397972, violated group size: 0.2952991277998444
# iteration: 77, error: 0.23872125172235728, fairness violation: 0.00023595566000291667, violated group size: 0.2952991277998444
# iteration: 78, error: 0.23872843779890995, fairness violation: 0.00023293058743877678, violated group size: 0.46541910650669505
# iteration: 79, error: 0.23873544194947385, fairness violation: 0.00022998209899018464, violated group size: 0.2952991277998444
# iteration: 80, error: 0.23874227099627368, fairness violation: 0.00022710732275280736, violated group size: 0.2952991277998444
# iteration: 81, error: 0.23874893142463402, fairness violation: 0.000224303528644748, violated group size: 0.2952991277998444
# iteration: 82, error: 0.23875542940352218, fairness violation: 0.0002215681197588364, violated group size: 0.2952991277998444
# iteration: 83, error: 0.23876177080460578, fairness violation: 0.00021889862434005538, violated group size: 0.46541910650669505
# iteration: 84, error: 0.23876796121994925, fairness violation: 0.00021629268833600707, violated group size: 0.46541910650669505
# iteration: 85, error: 0.23877400597846118, fairness violation: 0.00021374806847323046, violated group size: 0.46541910650669505
# iteration: 86, error: 0.2387799101611937, fairness violation: 0.00021126262581656495, violated group size: 0.2952991277998444
# iteration: 87, error: 0.2387856786155876, fairness violation: 0.00020883431977269647, violated group size: 0.46541910650669505
# iteration: 88, error: 0.23879131596874525, fairness violation: 0.00020646120250255215, violated group size: 0.2952991277998444
# iteration: 89, error: 0.23879682663980942, fairness violation: 0.00020414141371038867, violated group size: 0.2952991277998444
# iteration: 90, error: 0.23880221485151665, fairness violation: 0.0002018731757802732, violated group size: 0.2952991277998444
# iteration: 91, error: 0.2388074846409886, fairness violation: 0.00019965478923323723, violated group size: 0.2952991277998444
# iteration: 92, error: 0.2388126398698198, fairness violation: 0.00019748462848070213, violated group size: 0.46541910650669505
# iteration: 93, error: 0.23881768423351488, fairness violation: 0.00019536113785187728, violated group size: 0.46541910650669505
# iteration: 94, error: 0.2388226212703228, fairness violation: 0.00019328282787472968, violated group size: 0.46541910650669505
# iteration: 95, error: 0.23882745436951375, fairness violation: 0.00019124827179183774, violated group size: 0.46541910650669505
# iteration: 96, error: 0.2388321867791382, fairness violation: 0.00018925610229400614, violated group size: 0.46541910650669505
# iteration: 97, error: 0.2388368216133064, fairness violation: 0.0001873050084559236, violated group size: 0.2952991277998444
# iteration: 98, error: 0.2388413618590223, fairness violation: 0.00018539373285943457, violated group size: 0.2952991277998444
# iteration: 99, error: 0.2388458103826025, fairness violation: 0.00018352106889115753, violated group size: 0.46541910650669505
# iteration: 100, error: 0.23885016993571107, fairness violation: 0.00018168585820224587, violated group size: 0.2952991277998444
# iteration: 101, error: 0.23885444316103535, fairness violation: 0.0001798869883190553, violated group size: 0.2952991277998444
# iteration: 102, error: 0.23885863259762774, fairness violation: 0.00017812339039435866, violated group size: 0.2952991277998444
# iteration: 103, error: 0.23886274068593677, fairness violation: 0.0001763940370895591, violated group size: 0.46541910650669505
# iteration: 104, error: 0.2388667697725476, fairness violation: 0.00017469794057908255, violated group size: 0.46541910650669505
# iteration: 105, error: 0.23887072211465155, fairness violation: 0.00017303415066880555, violated group size: 0.2952991277998444
# iteration: 106, error: 0.23887459988426293, fairness violation: 0.00017140175302098667, violated group size: 0.46541910650669505
# iteration: 107, error: 0.23887840517219935, fairness violation: 0.00016979986747873443, violated group size: 0.2952991277998444
# iteration: 108, error: 0.23888213999184066, fairness violation: 0.00016822764648356098, violated group size: 0.46541910650669505
# iteration: 109, error: 0.2388858062826812, fairness violation: 0.00016668427358004206, violated group size: 0.2952991277998444
# iteration: 110, error: 0.23888940591368832, fairness violation: 0.0001651689620020417, violated group size: 0.2952991277998444
# iteration: 111, error: 0.23889294068647898, fairness violation: 0.00016368095333535676, violated group size: 0.46541910650669505
# iteration: 112, error: 0.23889641233832712, fairness violation: 0.00016221951625200524, violated group size: 0.2952991277998444
# iteration: 113, error: 0.23889982254500966, fairness violation: 0.00016078394531172203, violated group size: 0.2952991277998444
# iteration: 114, error: 0.23890317292350485, fairness violation: 0.00015937355982653144, violated group size: 0.2952991277998444
# iteration: 115, error: 0.23890646503454796, fairness violation: 0.00015798770278456164, violated group size: 0.2952991277998444
# iteration: 116, error: 0.23890970038505582, fairness violation: 0.00015662573982952232, violated group size: 0.2952991277998444
# iteration: 117, error: 0.2389128804304268, fairness violation: 0.00015528705829251786, violated group size: 0.2952991277998444
# iteration: 118, error: 0.23891600657672374, fairness violation: 0.00015397106627308978, violated group size: 0.2952991277998444
# iteration: 119, error: 0.2389190801827467, fairness violation: 0.0001526771917665932, violated group size: 0.46541910650669505
# iteration: 120, error: 0.23892210256200264, fairness violation: 0.00015140488183520493, violated group size: 0.2952991277998444
# iteration: 121, error: 0.23892507498457669, fairness violation: 0.000150153601820038, violated group size: 0.2952991277998444
# iteration: 122, error: 0.23892799867891185, fairness violation: 0.00014892283459200486, violated group size: 0.2952991277998444
# iteration: 123, error: 0.23893087483350162, fairness violation: 0.00014771207983922435, violated group size: 0.2952991277998444
# iteration: 124, error: 0.2389337045985013, fairness violation: 0.00014652085338890804, violated group size: 0.2952991277998444
# iteration: 125, error: 0.23893648908726098, fairness violation: 0.0001453486865617968, violated group size: 0.46541910650669505
# iteration: 126, error: 0.23893922937778636, fairness violation: 0.00014419512555733806, violated group size: 0.2952991277998444
# iteration: 127, error: 0.23894192651413027, fairness violation: 0.00014305973086791023, violated group size: 0.2952991277998444
# iteration: 128, error: 0.23894458150771877, fairness violation: 0.00014194207672050467, violated group size: 0.46541910650669505
# iteration: 129, error: 0.238947195338616, fairness violation: 0.00014084175054437673, violated group size: 0.46541910650669505
# iteration: 130, error: 0.23894976895673017, fairness violation: 0.00013975835246326615, violated group size: 0.2952991277998444
# iteration: 131, error: 0.23895230328296477, fairness violation: 0.00013869149481087481, violated group size: 0.2952991277998444
# iteration: 132, error: 0.238954799210317, fairness violation: 0.00013764080166836818, violated group size: 0.2952991277998444
# iteration: 133, error: 0.2389572576049271, fairness violation: 0.00013660590842274134, violated group size: 0.2952991277998444
# iteration: 134, error: 0.23895967930708034, fairness violation: 0.00013558646134495967, violated group size: 0.2952991277998444
# iteration: 135, error: 0.23896206513216464, fairness violation: 0.0001345821171868489, violated group size: 0.46541910650669505
# iteration: 136, error: 0.23896441587158593, fairness violation: 0.00013359254279576908, violated group size: 0.2952991277998444
# iteration: 137, error: 0.2389667322936434, fairness violation: 0.00013261741474616492, violated group size: 0.2952991277998444
# iteration: 138, error: 0.23896901514436672, fairness violation: 0.00013165641898713477, violated group size: 0.2952991277998444
# iteration: 139, error: 0.23897126514831704, fairness violation: 0.0001307092505052129, violated group size: 0.2952991277998444
# iteration: 140, error: 0.23897348300935375, fairness violation: 0.00012977561300160428, violated group size: 0.2952991277998444
# iteration: 141, error: 0.23897566941136875, fairness violation: 0.0001288552185831532, violated group size: 0.2952991277998444
# iteration: 142, error: 0.23897782501898907, fairness violation: 0.0001279477874663704, violated group size: 0.2952991277998444
# iteration: 143, error: 0.23897995047825113, fairness violation: 0.00012705304769387832, violated group size: 0.2952991277998444
# iteration: 144, error: 0.23898204641724563, fairness violation: 0.00012617073486267082, violated group size: 0.2952991277998444
# iteration: 145, error: 0.23898411344673676, fairness violation: 0.00012530059186361794, violated group size: 0.2952991277998444
# iteration: 146, error: 0.23898615216075544, fairness violation: 0.00012444236863167534, violated group size: 0.2952991277998444
# iteration: 147, error: 0.23890417720669205, fairness violation: 0.0001407348750752722, violated group size: 0.2952991277998444
# iteration: 148, error: 0.23882331002227808, fairness violation: 0.00015680721251287456, violated group size: 0.2952991277998444
# iteration: 149, error: 0.23874352830342688, fairness violation: 0.00017266381387748896, violated group size: 0.2952991277998444
# iteration: 150, error: 0.2386648103408269, fairness violation: 0.0001883089938905751, violated group size: 0.2952991277998444
# iteration: 151, error: 0.23858713500024817, fairness violation: 0.0002286976578241691, violated group size: 0.40272716104991607
# iteration: 152, error: 0.23851048170362438, fairness violation: 0.0002472872626704908, violated group size: 0.40272716104991607
# iteration: 153, error: 0.238434830410878, fairness violation: 0.0002656338661462723, violated group size: 0.40272716104991607
# iteration: 154, error: 0.23836016160245305, fairness violation: 0.0002837422020444463, violated group size: 0.3579910732566234
# iteration: 155, error: 0.23828645626252393, fairness violation: 0.0003016168819955471, violated group size: 0.40272716104991607
# iteration: 156, error: 0.2382136958628503, fairness violation: 0.0003192623993831724, violated group size: 0.40272716104991607
# iteration: 157, error: 0.2381418623472489, fairness violation: 0.0003366831331098085, violated group size: 0.3579910732566234
# iteration: 158, error: 0.2380709381166551, fairness violation: 0.0003538833512196519, violated group size: 0.40272716104991607
# iteration: 159, error: 0.2380009060147481, fairness violation: 0.00037086721438471743, violated group size: 0.40272716104991607
# iteration: 160, error: 0.2379317493141149, fairness violation: 0.0003876387792602197, violated group size: 0.40272716104991607
# iteration: 161, error: 0.23786345170293052, fairness violation: 0.00040420200171490805, violated group size: 0.3579910732566234
# iteration: 162, error: 0.23779599727213124, fairness violation: 0.0004205607399417609, violated group size: 0.3579910732566234
# iteration: 163, error: 0.23772937050305942, fairness violation: 0.000436718757454174, violated group size: 0.40272716104991607
# iteration: 164, error: 0.23766355625556174, fairness violation: 0.0004526797259725331, violated group size: 0.40272716104991607
# iteration: 165, error: 0.23759853975651857, fairness violation: 0.0004684472282058211, violated group size: 0.3579910732566234
# iteration: 166, error: 0.2375343065887891, fairness violation: 0.0004840247605326841, violated group size: 0.3579910732566234
# iteration: 167, error: 0.23747084268055346, fairness violation: 0.0004994157355861714, violated group size: 0.3579910732566234
# iteration: 168, error: 0.2374081342950349, fairness violation: 0.0005146234847461649, violated group size: 0.40272716104991607
# iteration: 169, error: 0.23734616802058758, fairness violation: 0.0005296512605433182, violated group size: 0.40272716104991607
# iteration: 170, error: 0.23728493076113374, fairness violation: 0.0005445022389781519, violated group size: 0.3579910732566234
# iteration: 171, error: 0.2372244097269367, fairness violation: 0.000559179521758777, violated group size: 0.3579910732566234
# iteration: 172, error: 0.23716459242569538, fairness violation: 0.0005736861384605581, violated group size: 0.40272716104991607
# iteration: 173, error: 0.23710546665394824, fairness violation: 0.000588025048610873, violated group size: 0.3579910732566234
# iteration: 174, error: 0.23704702048877285, fairness violation: 0.0006021991437019891, violated group size: 0.40272716104991607
# iteration: 175, error: 0.23698924227977092, fairness violation: 0.0006162112491349209, violated group size: 0.3579910732566234
# iteration: 176, error: 0.2369321206413258, fairness violation: 0.0006300641260970242, violated group size: 0.40272716104991607
# iteration: 177, error: 0.23687564444512305, fairness violation: 0.0006437604733759396, violated group size: 0.40272716104991607
# iteration: 178, error: 0.23681980281292256, fairness violation: 0.0006573029291123953, violated group size: 0.3579910732566234
# iteration: 179, error: 0.2367645851095735, fairness violation: 0.0006706940724942539, violated group size: 0.40272716104991607
# iteration: 180, error: 0.23670998093626164, fairness violation: 0.0006839364253940918, violated group size: 0.3579910732566234
# iteration: 181, error: 0.2366559801239808, fairness violation: 0.0006970324539524949, violated group size: 0.40272716104991607
# iteration: 182, error: 0.23660257272721957, fairness violation: 0.0007099845701091576, violated group size: 0.40272716104991607
# iteration: 183, error: 0.23654974901785455, fairness violation: 0.0007227951330837799, violated group size: 0.3579910732566234
# iteration: 184, error: 0.23649749947924362, fairness violation: 0.0007354664508086783, violated group size: 0.40272716104991607
# iteration: 185, error: 0.2364458148005095, fairness violation: 0.0007480007813149288, violated group size: 0.40272716104991607
# iteration: 186, error: 0.23639468587100912, fairness violation: 0.0007604003340738006, violated group size: 0.3579910732566234
# iteration: 187, error: 0.23634410377497933, fairness violation: 0.0007726672712951447, violated group size: 0.40272716104991607
# iteration: 188, error: 0.23629405978635407, fairness violation: 0.0007848037091843462, violated group size: 0.40272716104991607
# iteration: 189, error: 0.23624454536374603, fairness violation: 0.0007968117191593761, violated group size: 0.3579910732566234
# iteration: 190, error: 0.23619555214558652, fairness violation: 0.000808693329029406, violated group size: 0.3579910732566234
# iteration: 191, error: 0.2361470719454182, fairness violation: 0.000820450524136399, violated group size: 0.3579910732566234
# iteration: 192, error: 0.23609909674733492, fairness violation: 0.0008320852484610278, violated group size: 0.40272716104991607
# iteration: 193, error: 0.2360516187015634, fairness violation: 0.0008435994056942092, violated group size: 0.3579910732566234
# iteration: 194, error: 0.23600463012018133, fairness violation: 0.0008549948602755021, violated group size: 0.3579910732566234
# iteration: 195, error: 0.23595812347296727, fairness violation: 0.0008662734383995512, violated group size: 0.3579910732566234
# iteration: 196, error: 0.23591209138337782, fairness violation: 0.0008774369289917223, violated group size: 0.3579910732566234
# iteration: 197, error: 0.23586652662464713, fairness violation: 0.0008884870846540236, violated group size: 0.3579910732566234
# iteration: 198, error: 0.23582142211600465, fairness violation: 0.0008994256225823622, violated group size: 0.3579910732566234
# iteration: 199, error: 0.23577677091900678, fairness violation: 0.0009102542254561446, violated group size: 0.3579910732566234
# iteration: 200, error: 0.23573256623397898, fairness violation: 0.0009209745423011893, violated group size: 0.3579910732566234
# iteration: 201, error: 0.23568880139656334, fairness violation: 0.0009315881893268801, violated group size: 0.40272716104991607
# iteration: 202, error: 0.23555364012712646, fairness violation: 0.000976678070911913, violated group size: 0.40272716104991607
# iteration: 203, error: 0.23541981049581207, fairness violation: 0.0010213237172103935, violated group size: 0.40272716104991607
# iteration: 204, error: 0.2352872929197067, fairness violation: 0.001065531661094183, violated group size: 0.3579910732566234
# iteration: 205, error: 0.23515606819800233, fairness violation: 0.0011093083079644723, violated group size: 0.3579910732566234
# iteration: 206, error: 0.23502611750272226, fairness violation: 0.0011526599388457293, violated group size: 0.3579910732566234
# iteration: 207, error: 0.23489742236971548, fairness violation: 0.0011955927133899702, violated group size: 0.40272716104991607
# iteration: 208, error: 0.23476996468991063, fairness violation: 0.0012381126727943619, violated group size: 0.3579910732566234
# iteration: 209, error: 0.23464372670082165, fairness violation: 0.001280225742635075, violated group size: 0.3579910732566234
# iteration: 210, error: 0.2345186909782954, fairness violation: 0.0013219377356201627, violated group size: 0.3579910732566234
# iteration: 211, error: 0.23439484042849454, fairness violation: 0.0013632543542641596, violated group size: 0.3579910732566234
# iteration: 212, error: 0.23427215828010692, fairness violation: 0.0014041811934869866, violated group size: 0.40272716104991607
# iteration: 213, error: 0.2341506280767745, fairness violation: 0.0014447237431396461, violated group size: 0.40272716104991607
# iteration: 214, error: 0.23403023366973502, fairness violation: 0.0014848873904591035, violated group size: 0.40272716104991607
# iteration: 215, error: 0.23391095921066793, fairness violation: 0.0015246774224546588, violated group size: 0.3579910732566234
# iteration: 216, error: 0.23379278914474033, fairness violation: 0.0015640990282280328, violated group size: 0.40272716104991607
# iteration: 217, error: 0.23367570820384437, fairness violation: 0.0016031573012293017, violated group size: 0.3579910732566234
# iteration: 218, error: 0.2335597014000208, fairness violation: 0.0016418572414507431, violated group size: 0.3579910732566234
# iteration: 219, error: 0.23344475401906323, fairness violation: 0.0016802037575605728, violated group size: 0.40272716104991607
# iteration: 220, error: 0.2333308516142962, fairness violation: 0.0017182016689784951, violated group size: 0.3579910732566234
# iteration: 221, error: 0.23321798000052255, fairness violation: 0.001755855707894898, violated group size: 0.40272716104991607
# iteration: 222, error: 0.23310612524813418, fairness violation: 0.0017931705212354768, violated group size: 0.40272716104991607
# iteration: 223, error: 0.23299527367738157, fairness violation: 0.0018301506725730016, violated group size: 0.40272716104991607
# iteration: 224, error: 0.2328854118527965, fairness violation: 0.0018668006439878698, violated group size: 0.40272716104991607
# iteration: 225, error: 0.2327765265777632, fairness violation: 0.0019031248378790502, violated group size: 0.40272716104991607
# iteration: 226, error: 0.2326686048892347, fairness violation: 0.0019391275787269458, violated group size: 0.40272716104991607
# iteration: 227, error: 0.23256163405258742, fairness violation: 0.0019748131148096615, violated group size: 0.40272716104991607
# iteration: 228, error: 0.23245560155661255, fairness violation: 0.002010185619874108, violated group size: 0.3579910732566234
# iteration: 229, error: 0.23235049510863745, fairness violation: 0.00204524919476332, violated group size: 0.40272716104991607
# iteration: 230, error: 0.23224630262977516, fairness violation: 0.0020800078690013206, violated group size: 0.40272716104991607
# iteration: 231, error: 0.232143012250297, fairness violation: 0.0021144656023368274, violated group size: 0.3579910732566234
# iteration: 232, error: 0.23204061230512457, fairness violation: 0.0021486262862470285, violated group size: 0.3579910732566234
# iteration: 233, error: 0.23193909132943874, fairness violation: 0.0021824937454026356, violated group size: 0.40272716104991607
# iteration: 234, error: 0.23183843805439974, fairness violation: 0.0022160717390953748, violated group size: 0.40272716104991607
# iteration: 235, error: 0.23173864140297806, fairness violation: 0.002249363962629026, violated group size: 0.3579910732566234
# iteration: 236, error: 0.23163969048589053, fairness violation: 0.0022823740486751037, violated group size: 0.3579910732566234
# iteration: 237, error: 0.2315415745976391, fairness violation: 0.0023151055685942112, violated group size: 0.3579910732566234
# iteration: 238, error: 0.23144428321265037, fairness violation: 0.0023475620337240813, violated group size: 0.3579910732566234
# iteration: 239, error: 0.2313478059815109, fairness violation: 0.0023797468966352928, violated group size: 0.3579910732566234
# iteration: 240, error: 0.23125213272729755, fairness violation: 0.002411663552355577, violated group size: 0.3579910732566234
# iteration: 241, error: 0.23115725344199883, fairness violation: 0.002443315339563659, violated group size: 0.3579910732566234
# iteration: 242, error: 0.23106315828302493, fairness violation: 0.002474705541753494, violated group size: 0.40272716104991607
# iteration: 243, error: 0.23096983756980388, fairness violation: 0.0025058373883697486, violated group size: 0.3579910732566234
# iteration: 244, error: 0.23087728178046174, fairness violation: 0.002536714055915379, violated group size: 0.40272716104991607
# iteration: 245, error: 0.23078548154858355, fairness violation: 0.002567338669032065, violated group size: 0.40272716104991607
# iteration: 246, error: 0.23069442766005402, fairness violation: 0.0025977143015543064, violated group size: 0.3579910732566234
# iteration: 247, error: 0.23060411104997408, fairness violation: 0.0026278439775379065, violated group size: 0.40272716104991607
# iteration: 248, error: 0.23051452279965287, fairness violation: 0.0026577306722635743, violated group size: 0.40272716104991607
# iteration: 249, error: 0.23042565413367158, fairness violation: 0.0026873773132163443, violated group size: 0.40272716104991607
# iteration: 250, error: 0.23033749641701812, fairness violation: 0.0027167867810414933, violated group size: 0.40272716104991607
# iteration: 251, error: 0.23025004115229022, fairness violation: 0.0027459619104775964, violated group size: 0.40272716104991607
# iteration: 252, error: 0.23016327997696492, fairness violation: 0.002774905491267381, violated group size: 0.3579910732566234
# iteration: 253, error: 0.23007720466073306, fairness violation: 0.00280362026904697, violated group size: 0.40272716104991607
# iteration: 254, error: 0.2299918071028968, fairness violation: 0.0028321089462141225, violated group size: 0.40272716104991607
# iteration: 255, error: 0.22990707932982785, fairness violation: 0.0028603741827760423, violated group size: 0.40272716104991607
# iteration: 256, error: 0.22982301349248596, fairness violation: 0.0028884185971773204, violated group size: 0.3579910732566234
# iteration: 257, error: 0.22973960186399506, fairness violation: 0.0029162447671085504, violated group size: 0.3579910732566234
# iteration: 258, error: 0.22965683683727534, fairness violation: 0.0029438552302961277, violated group size: 0.3579910732566234
# iteration: 259, error: 0.22957471092273107, fairness violation: 0.002971252485273762, violated group size: 0.3579910732566234
# iteration: 260, error: 0.22949321674599102, fairness violation: 0.002998438992136185, violated group size: 0.3579910732566234
# iteration: 261, error: 0.22941234704570101, fairness violation: 0.003025417173275523, violated group size: 0.40272716104991607
# iteration: 262, error: 0.2293320946713675, fairness violation: 0.00305218941410082, violated group size: 0.40272716104991607
# iteration: 263, error: 0.22925245258124943, fairness violation: 0.003078758063741136, violated group size: 0.40272716104991607
# iteration: 264, error: 0.22917341384029893, fairness violation: 0.0031051254357326577, violated group size: 0.3579910732566234
# iteration: 265, error: 0.229094971618148, fairness violation: 0.0031312938086902843, violated group size: 0.40272716104991607
# iteration: 266, error: 0.2290171191871411, fairness violation: 0.003157265426964017, violated group size: 0.3579910732566234
# iteration: 267, error: 0.22893984992041141, fairness violation: 0.0031830425012806447, violated group size: 0.3579910732566234
# iteration: 268, error: 0.22886315729000062, fairness violation: 0.0032086272093710287, violated group size: 0.3579910732566234
# iteration: 269, error: 0.2287870348650203, fairness violation: 0.0032340216965834165, violated group size: 0.40272716104991607
# iteration: 270, error: 0.22871147630985475, fairness violation: 0.0032592280764831205, violated group size: 0.40272716104991607
# iteration: 271, error: 0.2286364753824026, fairness violation: 0.003284248431438916, violated group size: 0.40272716104991607
# iteration: 272, error: 0.22856202593235814, fairness violation: 0.003309084813196506, violated group size: 0.3579910732566234
# iteration: 273, error: 0.22848812189953013, fairness violation: 0.003333739243439388, violated group size: 0.3579910732566234
# iteration: 274, error: 0.22841475731219718, fairness violation: 0.0033582137143374313, violated group size: 0.3579910732566234
# iteration: 275, error: 0.22834192628549946, fairness violation: 0.003382510189083492, violated group size: 0.40272716104991607
# iteration: 276, error: 0.2282696230198647, fairness violation: 0.003406630602418346, violated group size: 0.3579910732566234
# iteration: 277, error: 0.2281956982930445, fairness violation: 0.003428542082225199, violated group size: 0.40272716104991607
# iteration: 278, error: 0.22812230539879141, fairness violation: 0.0034502959254866794, violated group size: 0.3579910732566234
# iteration: 279, error: 0.22804943861847557, fairness violation: 0.003471893827219405, violated group size: 0.40272716104991607
# iteration: 280, error: 0.22797709231516197, fairness violation: 0.003493337458225467, violated group size: 0.40272716104991607
# iteration: 281, error: 0.2279052609321567, fairness violation: 0.0035146284655233, violated group size: 0.40272716104991607
# iteration: 282, error: 0.22783393899158413, fairness violation: 0.003535768472769377, violated group size: 0.3579910732566234
# iteration: 283, error: 0.2277631210929943, fairness violation: 0.003556759080670959, violated group size: 0.40272716104991607
# iteration: 284, error: 0.22769280191200025, fairness violation: 0.0035776018673901342, violated group size: 0.3579910732566234
# iteration: 285, error: 0.22762297619894295, fairness violation: 0.0035982983889393506, violated group size: 0.40272716104991607
# iteration: 286, error: 0.2275536387775854, fairness violation: 0.003618850179568643, violated group size: 0.40272716104991607
# iteration: 287, error: 0.22748478454383309, fairness violation: 0.0036392587521447686, violated group size: 0.3579910732566234
# iteration: 288, error: 0.22741640846448186, fairness violation: 0.0036595255985224498, violated group size: 0.3579910732566234
# iteration: 289, error: 0.22734850557599115, fairness violation: 0.0036796521899078974, violated group size: 0.40272716104991607
# iteration: 290, error: 0.2272810709832832, fairness violation: 0.003699639977214825, violated group size: 0.3579910732566234
# iteration: 291, error: 0.22721409985856636, fairness violation: 0.0037194903914131135, violated group size: 0.40272716104991607
# iteration: 292, error: 0.22714758744018315, fairness violation: 0.0037392048438703177, violated group size: 0.3579910732566234
# iteration: 293, error: 0.22708152903148174, fairness violation: 0.003758784726686177, violated group size: 0.40272716104991607
# iteration: 294, error: 0.2270159199997103, fairness violation: 0.0037782314130202946, violated group size: 0.3579910732566234
# iteration: 295, error: 0.22695075577493393, fairness violation: 0.0037975462574131647, violated group size: 0.40272716104991607
# iteration: 296, error: 0.22688603184897355, fairness violation: 0.0038167305961006774, violated group size: 0.40272716104991607
# iteration: 297, error: 0.2268217437743665, fairness violation: 0.0038357857473222796, violated group size: 0.3579910732566234
# iteration: 298, error: 0.22675788716334744, fairness violation: 0.0038547130116229327, violated group size: 0.3579910732566234
# iteration: 299, error: 0.2266944576868502, fairness violation: 0.0038735136721489987, violated group size: 0.3579910732566234
# iteration: 300, error: 0.2266314510735296, fairness violation: 0.003892188994938225, violated group size: 0.40272716104991607
# iteration: 301, error: 0.22656886310880253, fairness violation: 0.003910740229203935, violated group size: 0.40272716104991607
# iteration: 302, error: 0.2265066896339081, fairness violation: 0.00392916860761358, violated group size: 0.3579910732566234
# iteration: 303, error: 0.22644492654498652, fairness violation: 0.003947475346561778, violated group size: 0.40272716104991607
# iteration: 304, error: 0.2263835697921763, fairness violation: 0.003965661646437944, violated group size: 0.3579910732566234
# iteration: 305, error: 0.22632261537872875, fairness violation: 0.003983728691888695, violated group size: 0.40272716104991607
# iteration: 306, error: 0.22626205936014035, fairness violation: 0.004001677652075062, violated group size: 0.40272716104991607
# iteration: 307, error: 0.2262018978433017, fairness violation: 0.004019509680924708, violated group size: 0.3579910732566234
# iteration: 308, error: 0.2261421269856633, fairness violation: 0.004037225917379228, violated group size: 0.3579910732566234
# iteration: 309, error: 0.22608274299441738, fairness violation: 0.004054827485636632, violated group size: 0.40272716104991607
# iteration: 310, error: 0.22602374212569562, fairness violation: 0.004072315495389149, violated group size: 0.40272716104991607
# iteration: 311, error: 0.22596512068378238, fairness violation: 0.004089691042056442, violated group size: 0.40272716104991607
# iteration: 312, error: 0.2259068750203429, fairness violation: 0.004106955207014327, violated group size: 0.3579910732566234
# iteration: 313, error: 0.2258490015336667, fairness violation: 0.004124109057819126, violated group size: 0.3579910732566234
# iteration: 314, error: 0.22579149666792467, fairness violation: 0.0041411536484277185, violated group size: 0.3579910732566234
# iteration: 315, error: 0.22573435691244131, fairness violation: 0.0041580900194133985, violated group size: 0.40272716104991607
# iteration: 316, error: 0.22567757880098008, fairness violation: 0.0041749191981776505, violated group size: 0.3579910732566234
# iteration: 317, error: 0.2256211589110422, fairness violation: 0.004191642199157899, violated group size: 0.3579910732566234
# iteration: 318, error: 0.22556509386317944, fairness violation: 0.004208260024031355, violated group size: 0.3579910732566234
# iteration: 319, error: 0.2255093803203189, fairness violation: 0.004224773661915009, violated group size: 0.3579910732566234
# iteration: 320, error: 0.22545401498710127, fairness violation: 0.00424118408956189, violated group size: 0.3579910732566234
# iteration: 321, error: 0.22539899460923077, fairness violation: 0.004257492271553649, violated group size: 0.3579910732566234
# iteration: 322, error: 0.2253443159728378, fairness violation: 0.004273699160489562, violated group size: 0.40272716104991607
# iteration: 323, error: 0.22528997590385275, fairness violation: 0.004289805697172, violated group size: 0.40272716104991607
# iteration: 324, error: 0.22523597126739234, fairness violation: 0.004305812810788495, violated group size: 0.3579910732566234
# iteration: 325, error: 0.22518229896715622, fairness violation: 0.004321721419090428, violated group size: 0.3579910732566234
# iteration: 326, error: 0.22512895594483576, fairness violation: 0.0043375324285684245, violated group size: 0.40272716104991607
# iteration: 327, error: 0.22507593917953253, fairness violation: 0.004353246734624536, violated group size: 0.40272716104991607
# iteration: 328, error: 0.22502324568718848, fairness violation: 0.004368865221741281, violated group size: 0.40272716104991607
# iteration: 329, error: 0.22497087252002584, fairness violation: 0.004384388763647587, violated group size: 0.3579910732566234
# iteration: 330, error: 0.22491881676599745, fairness violation: 0.004399818223481739, violated group size: 0.40272716104991607
# iteration: 331, error: 0.22486707554824725, fairness violation: 0.004415154453951331, violated group size: 0.3579910732566234
# iteration: 332, error: 0.22481564602457985, fairness violation: 0.004430398297490382, violated group size: 0.3579910732566234
# iteration: 333, error: 0.2247645253869405, fairness violation: 0.004445550586413587, violated group size: 0.40272716104991607
# iteration: 334, error: 0.22471371086090383, fairness violation: 0.004460612143067787, violated group size: 0.3579910732566234
# iteration: 335, error: 0.2246631997051718, fairness violation: 0.004475583779980769, violated group size: 0.3579910732566234
# iteration: 336, error: 0.22461298921108103, fairness violation: 0.004490466300007365, violated group size: 0.3579910732566234
# iteration: 337, error: 0.22456307670211836, fairness violation: 0.004505260496472972, violated group size: 0.3579910732566234
# iteration: 338, error: 0.22451345953344548, fairness violation: 0.004519967153314522, violated group size: 0.40272716104991607
# iteration: 339, error: 0.22446413509143145, fairness violation: 0.004534587045218954, violated group size: 0.40272716104991607
# iteration: 340, error: 0.2244151007931939, fairness violation: 0.00454912093775924, violated group size: 0.3579910732566234
# iteration: 341, error: 0.2243663540861484, fairness violation: 0.004563569587528031, violated group size: 0.3579910732566234
# iteration: 342, error: 0.22431789244756514, fairness violation: 0.004577933742268934, violated group size: 0.3579910732566234
# iteration: 343, error: 0.22426971338413398, fairness violation: 0.004592214141005518, violated group size: 0.40272716104991607
# iteration: 344, error: 0.2242218144315367, fairness violation: 0.0046064115141680505, violated group size: 0.40272716104991607
# iteration: 345, error: 0.22417419315402695, fairness violation: 0.004620526583718047, violated group size: 0.3579910732566234
# iteration: 346, error: 0.2241268471440173, fairness violation: 0.004634560063270646, violated group size: 0.40272716104991607
# iteration: 347, error: 0.2240797740216734, fairness violation: 0.004648512658214872, violated group size: 0.40272716104991607
# iteration: 348, error: 0.22403297143451537, fairness violation: 0.004662385065831831, violated group size: 0.40272716104991607
# iteration: 349, error: 0.2239864370570258, fairness violation: 0.00467617797541087, violated group size: 0.3579910732566234
# iteration: 350, error: 0.22394016859026483, fairness violation: 0.004689892068363744, violated group size: 0.3579910732566234
# iteration: 351, error: 0.22389416376149107, fairness violation: 0.00470352801833683, violated group size: 0.3579910732566234
# iteration: 352, error: 0.2238484203237899, fairness violation: 0.004717086491321432, violated group size: 0.3579910732566234
# iteration: 353, error: 0.22380293605570742, fairness violation: 0.004730568145762212, violated group size: 0.3579910732566234
# iteration: 354, error: 0.22375770876089096, fairness violation: 0.004743973632663779, violated group size: 0.3579910732566234
# iteration: 355, error: 0.22371273626773538, fairness violation: 0.004757303595695479, violated group size: 0.40272716104991607
# iteration: 356, error: 0.22366801642903578, fairness violation: 0.004770558671294415, violated group size: 0.40272716104991607
# iteration: 357, error: 0.22362354712164545, fairness violation: 0.004783739488766746, violated group size: 0.3579910732566234
# iteration: 358, error: 0.22357932624613996, fairness violation: 0.004796846670387278, violated group size: 0.40272716104991607
# iteration: 359, error: 0.22353535172648684, fairness violation: 0.004809880831497388, violated group size: 0.3579910732566234
# iteration: 360, error: 0.22349162150972068, fairness violation: 0.004822842580601331, violated group size: 0.3579910732566234
# iteration: 361, error: 0.22344813356562362, fairness violation: 0.0048357325194609314, violated group size: 0.3579910732566234
# iteration: 362, error: 0.22340488588641105, fairness violation: 0.004848551243188709, violated group size: 0.3579910732566234
# iteration: 363, error: 0.2233618764864228, fairness violation: 0.004861299340339477, violated group size: 0.3579910732566234
# iteration: 364, error: 0.2233191034018191, fairness violation: 0.004873977393000402, violated group size: 0.3579910732566234
# iteration: 365, error: 0.2232765646902817, fairness violation: 0.0048865859768796255, violated group size: 0.3579910732566234
# iteration: 366, error: 0.22323425843072, fairness violation: 0.004899125661393389, violated group size: 0.3579910732566234
# iteration: 367, error: 0.2231921827229814, fairness violation: 0.004911597009751764, violated group size: 0.40272716104991607
# iteration: 368, error: 0.22315033568756754, fairness violation: 0.004924000579042973, violated group size: 0.3579910732566234
# iteration: 369, error: 0.22310871546535377, fairness violation: 0.004936336920316346, violated group size: 0.40272716104991607
# iteration: 370, error: 0.22306732021731407, fairness violation: 0.004948606578663912, violated group size: 0.3579910732566234
# iteration: 371, error: 0.2230261481242504, fairness violation: 0.004960810093300714, violated group size: 0.3579910732566234
# iteration: 372, error: 0.2229851973865257, fairness violation: 0.004972947997643767, violated group size: 0.3579910732566234
# iteration: 373, error: 0.2229444662238022, fairness violation: 0.004985020819389808, violated group size: 0.40272716104991607
# iteration: 374, error: 0.22290395287478318, fairness violation: 0.004997029080591752, violated group size: 0.40272716104991607
# iteration: 375, error: 0.2228636555969589, fairness violation: 0.005008973297733953, violated group size: 0.40272716104991607
# iteration: 376, error: 0.22281273659659856, fairness violation: 0.005023791345185523, violated group size: 0.3579910732566234
# iteration: 377, error: 0.22274193939055584, fairness violation: 0.005061557835938677, violated group size: 0.40272716104991607
# iteration: 378, error: 0.2226760665911397, fairness violation: 0.005094727754595834, violated group size: 0.3579910732566234
# iteration: 379, error: 0.22262183191744553, fairness violation: 0.005112352223591784, violated group size: 0.3579910732566234
# iteration: 380, error: 0.22258964997769393, fairness violation: 0.0051593915718398855, violated group size: 0.40272716104991607
# iteration: 381, error: 0.22264146826861828, fairness violation: 0.0052383363479257365, violated group size: 0.3579910732566234
# iteration: 382, error: 0.22285386086260406, fairness violation: 0.005375562054132219, violated group size: 0.40272716104991607
# iteration: 383, error: 0.22336937038843105, fairness violation: 0.005525759197874896, violated group size: 0.3579910732566234
# iteration: 384, error: 0.2243410512468777, fairness violation: 0.005673823107935538, violated group size: 0.3579910732566234
# iteration: 385, error: 0.22559900277438458, fairness violation: 0.005731750177588956, violated group size: 0.40272716104991607
# iteration: 386, error: 0.22698399597899793, fairness violation: 0.005717603098811561, violated group size: 0.40272716104991607
# iteration: 387, error: 0.22836315421757042, fairness violation: 0.005702828930597573, violated group size: 0.3579910732566234
# iteration: 388, error: 0.22973520339305745, fairness violation: 0.005688130917889847, violated group size: 0.3579910732566234
# iteration: 389, error: 0.23110019833113837, fairness violation: 0.00567350847337085, violated group size: 0.40272716104991607
# iteration: 390, error: 0.23245819329517786, fairness violation: 0.005658961015746824, violated group size: 0.40272716104991607
# iteration: 391, error: 0.23380924199341663, fairness violation: 0.005644487969670747, violated group size: 0.40272716104991607
# iteration: 392, error: 0.23515339758605214, fairness violation: 0.005630088765666483, violated group size: 0.3579910732566234
# iteration: 393, error: 0.23649071269221117, fairness violation: 0.0056157628400541, violated group size: 0.3579910732566234
# iteration: 394, error: 0.23782123939681604, fairness violation: 0.0056015096348762975, violated group size: 0.3579910732566234
# iteration: 395, error: 0.239145029257347, fairness violation: 0.005587328597825975, violated group size: 0.3579910732566234
# iteration: 396, error: 0.24046213331050154, fairness violation: 0.005573219182174901, violated group size: 0.3579910732566234
# iteration: 397, error: 0.24177260207875353, fairness violation: 0.005559180846703432, violated group size: 0.40272716104991607
# iteration: 398, error: 0.2430764855768133, fairness violation: 0.005545213055631314, violated group size: 0.40272716104991607
# iteration: 399, error: 0.2443738333179905, fairness violation: 0.005531315278549532, violated group size: 0.40272716104991607
# iteration: 400, error: 0.24566469432046192, fairness violation: 0.005517486990353156, violated group size: 0.3579910732566234
# iteration: 401, error: 0.2469491171134447, fairness violation: 0.005503727671175217, violated group size: 0.3579910732566234
# iteration: 402, error: 0.24822714974327822, fairness violation: 0.005490036806321548, violated group size: 0.40272716104991607
# iteration: 403, error: 0.24949883977941534, fairness violation: 0.005476413886206605, violated group size: 0.40272716104991607
# iteration: 404, error: 0.2507642343203241, fairness violation: 0.005462858406290254, violated group size: 0.3579910732566234
# iteration: 405, error: 0.25202337999930235, fairness violation: 0.0054493698670154645, violated group size: 0.3579910732566234
# iteration: 406, error: 0.25327632299020686, fairness violation: 0.0054359477737469545, violated group size: 0.40272716104991607
# iteration: 407, error: 0.2545231090130972, fairness violation: 0.005422591636710717, violated group size: 0.3579910732566234
# iteration: 408, error: 0.25576378333979677, fairness violation: 0.005409300970934469, violated group size: 0.3579910732566234
# iteration: 409, error: 0.2569983907993732, fairness violation: 0.005396075296188902, violated group size: 0.40272716104991607
# iteration: 410, error: 0.2582269757835369, fairness violation: 0.005382914136929917, violated group size: 0.40272716104991607
# iteration: 411, error: 0.25944958225196274, fairness violation: 0.005369817022241513, violated group size: 0.40272716104991607
# iteration: 412, error: 0.2606662537375321, fairness violation: 0.005356783485779765, violated group size: 0.40272716104991607
# iteration: 413, error: 0.26187703335150064, fairness violation: 0.005343813065717347, violated group size: 0.3579910732566234
# iteration: 414, error: 0.26308196378859006, fairness violation: 0.005330905304689043, violated group size: 0.40272716104991607
# iteration: 415, error: 0.2642810873320069, fairness violation: 0.005318059749737984, violated group size: 0.40272716104991607
# iteration: 416, error: 0.2654744458583879, fairness violation: 0.005305275952262656, violated group size: 0.40272716104991607
# iteration: 417, error: 0.2666620808426761, fairness violation: 0.005292553467964656, violated group size: 0.40272716104991607
# iteration: 418, error: 0.26784403336292456, fairness violation: 0.005279891856797278, violated group size: 0.40272716104991607
# iteration: 419, error: 0.2690203441050334, fairness violation: 0.005267290682914712, violated group size: 0.3579910732566234
# iteration: 420, error: 0.27019105336741794, fairness violation: 0.005254749514622057, violated group size: 0.40272716104991607
# iteration: 421, error: 0.27135620106561065, fairness violation: 0.005242267924326043, violated group size: 0.40272716104991607
# iteration: 422, error: 0.27251582673679764, fairness violation: 0.005229845488486405, violated group size: 0.40272716104991607
# iteration: 423, error: 0.2736699695442912, fairness violation: 0.005217481787567998, violated group size: 0.3579910732566234
# iteration: 424, error: 0.27481866828193796, fairness violation: 0.005205176405993548, violated group size: 0.40272716104991607
# iteration: 425, error: 0.27596196137846646, fairness violation: 0.005192928932097085, violated group size: 0.3579910732566234
# iteration: 426, error: 0.2770998869017718, fairness violation: 0.005180738958078077, violated group size: 0.3579910732566234
# iteration: 427, error: 0.27823248256314126, fairness violation: 0.005168606079956119, violated group size: 0.40272716104991607
# iteration: 428, error: 0.2793597857214203, fairness violation: 0.005156529897526316, violated group size: 0.40272716104991607
# iteration: 429, error: 0.2804818333871198, fairness violation: 0.005144510014315297, violated group size: 0.40272716104991607
# iteration: 430, error: 0.2815986622264673, fairness violation: 0.00513254603753782, violated group size: 0.40272716104991607
# iteration: 431, error: 0.2827103085654002, fairness violation: 0.005120637578053962, violated group size: 0.3579910732566234
# iteration: 432, error: 0.28381680839350465, fairness violation: 0.005108784250326996, violated group size: 0.40272716104991607
# iteration: 433, error: 0.28491819736789975, fairness violation: 0.005096985672381676, violated group size: 0.3579910732566234
# iteration: 434, error: 0.286014510817067, fairness violation: 0.0050852414657632725, violated group size: 0.40272716104991607
# iteration: 435, error: 0.28710578374462903, fairness violation: 0.0050735512554971555, violated group size: 0.3579910732566234
# iteration: 436, error: 0.28819205083307375, fairness violation: 0.005061914670048767, violated group size: 0.40272716104991607
# iteration: 437, error: 0.2892733464474295, fairness violation: 0.005050331341284357, violated group size: 0.40272716104991607
# iteration: 438, error: 0.2903497046388887, fairness violation: 0.0050388009044321095, violated group size: 0.40272716104991607
# iteration: 439, error: 0.29142115914838224, fairness violation: 0.005027322998043875, violated group size: 0.3579910732566234
# iteration: 440, error: 0.2924877434101053, fairness violation: 0.005015897263957423, violated group size: 0.3579910732566234
# iteration: 441, error: 0.2935494905549952, fairness violation: 0.0050045233472591055, violated group size: 0.3579910732566234
# iteration: 442, error: 0.2946064334141616, fairness violation: 0.004993200896247205, violated group size: 0.40272716104991607
# iteration: 443, error: 0.2956586045222708, fairness violation: 0.004981929562395635, violated group size: 0.40272716104991607
# iteration: 444, error: 0.29670603612088403, fairness violation: 0.004970709000318162, violated group size: 0.3579910732566234
# iteration: 445, error: 0.29774876016175067, fairness violation: 0.0049595388677331756, violated group size: 0.3579910732566234
# iteration: 446, error: 0.29878680831005733, fairness violation: 0.004948418825428841, violated group size: 0.3579910732566234
# iteration: 447, error: 0.29982021194763336, fairness violation: 0.004937348537228772, violated group size: 0.40272716104991607
# iteration: 448, error: 0.300849002176113, fairness violation: 0.00492632766995818, violated group size: 0.3579910732566234
# iteration: 449, error: 0.3018732098200561, fairness violation: 0.004915355893410378, violated group size: 0.3579910732566234
# iteration: 450, error: 0.3028928654300261, fairness violation: 0.004904432880313915, violated group size: 0.40272716104991607
# iteration: 451, error: 0.30390799928562806, fairness violation: 0.004893558306299923, violated group size: 0.40272716104991607
# iteration: 452, error: 0.3049186413985062, fairness violation: 0.004882731849870054, violated group size: 0.40272716104991607
# iteration: 453, error: 0.305924821515301, fairness violation: 0.0048719531923648056, violated group size: 0.40272716104991607
# iteration: 454, error: 0.30692656912056804, fairness violation: 0.004861222017932296, violated group size: 0.3579910732566234
# iteration: 455, error: 0.307923913439658, fairness violation: 0.004850538013497282, violated group size: 0.3579910732566234
# iteration: 456, error: 0.30891688344155915, fairness violation: 0.004839900868730844, violated group size: 0.3579910732566234
# iteration: 457, error: 0.30990550784170134, fairness violation: 0.004829310276020266, violated group size: 0.3579910732566234
# iteration: 458, error: 0.310889815104725, fairness violation: 0.00481876593043944, violated group size: 0.3579910732566234
# iteration: 459, error: 0.31186983344721264, fairness violation: 0.004808267529719522, violated group size: 0.3579910732566234
# iteration: 460, error: 0.3128455908403851, fairness violation: 0.004797814774220138, violated group size: 0.3579910732566234
# iteration: 461, error: 0.3138171150127628, fairness violation: 0.0047874073669008, violated group size: 0.3579910732566234
# iteration: 462, error: 0.31478443345279267, fairness violation: 0.004777045013292766, violated group size: 0.40272716104991607
# iteration: 463, error: 0.3157475734114401, fairness violation: 0.004766727421471404, violated group size: 0.40272716104991607
# iteration: 464, error: 0.3167065619047484, fairness violation: 0.004756454302028587, violated group size: 0.40272716104991607
# iteration: 465, error: 0.3176614257163652, fairness violation: 0.0047462253680457265, violated group size: 0.40272716104991607
# iteration: 466, error: 0.3186121914000351, fairness violation: 0.004736040335067097, violated group size: 0.3579910732566234
# iteration: 467, error: 0.3195588852820619, fairness violation: 0.004725898921073379, violated group size: 0.40272716104991607
# iteration: 468, error: 0.32050153346373805, fairness violation: 0.004715800846455695, violated group size: 0.3579910732566234
# iteration: 469, error: 0.3214401618237441, fairness violation: 0.0047057458339899, violated group size: 0.3579910732566234
# iteration: 470, error: 0.322374796020516, fairness violation: 0.004695733608811199, violated group size: 0.3579910732566234
# iteration: 471, error: 0.32330546149458395, fairness violation: 0.004685763898389097, violated group size: 0.3579910732566234
# iteration: 472, error: 0.32423218347088045, fairness violation: 0.00467583643250268, violated group size: 0.40272716104991607
# iteration: 473, error: 0.32515498696101924, fairness violation: 0.004665950943216196, violated group size: 0.40272716104991607
# iteration: 474, error: 0.3260738967655457, fairness violation: 0.0046561071648549964, violated group size: 0.40272716104991607
# iteration: 475, error: 0.32698893747615837, fairness violation: 0.0046463048339816255, violated group size: 0.3579910732566234
# iteration: 476, error: 0.3279001334779028, fairness violation: 0.0046365436893724184, violated group size: 0.40272716104991607
# iteration: 477, error: 0.32880750895133815, fairness violation: 0.004626823471994256, violated group size: 0.40272716104991607
# iteration: 478, error: 0.3297110878746753, fairness violation: 0.00461714392498172, violated group size: 0.40272716104991607
# iteration: 479, error: 0.33061089402589017, fairness violation: 0.004607504793614348, violated group size: 0.3579910732566234
# iteration: 480, error: 0.3315069509848082, fairness violation: 0.004597905825294316, violated group size: 0.40272716104991607
# iteration: 481, error: 0.3323992821351652, fairness violation: 0.0045883467695244555, violated group size: 0.3579910732566234
# iteration: 482, error: 0.33328791066664104, fairness violation: 0.004578827377886444, violated group size: 0.40272716104991607
# iteration: 483, error: 0.33417285957686854, fairness violation: 0.004569347404019191, violated group size: 0.40272716104991607
# iteration: 484, error: 0.33505415167341746, fairness violation: 0.004559906603597646, violated group size: 0.3579910732566234
# iteration: 485, error: 0.3359318095757538, fairness violation: 0.004550504734311883, violated group size: 0.3579910732566234
# iteration: 486, error: 0.33680585571717514, fairness violation: 0.004541141555846243, violated group size: 0.40272716104991607
# iteration: 487, error: 0.33767631234672213, fairness violation: 0.004531816829858854, violated group size: 0.40272716104991607
# iteration: 488, error: 0.3385432015310661, fairness violation: 0.0045225303199616165, violated group size: 0.40272716104991607
# iteration: 489, error: 0.3394065451563737, fairness violation: 0.004513281791699915, violated group size: 0.3579910732566234
# iteration: 490, error: 0.3402663649301496, fairness violation: 0.004504071012533181, violated group size: 0.3579910732566234
# iteration: 491, error: 0.34112268238305465, fairness violation: 0.004494897751815219, violated group size: 0.40272716104991607
# iteration: 492, error: 0.34197551887070393, fairness violation: 0.0044857617807749425, violated group size: 0.3579910732566234
# iteration: 493, error: 0.342824895575442, fairness violation: 0.004476662872497493, violated group size: 0.3579910732566234
# iteration: 494, error: 0.343670833508096, fairness violation: 0.004467600801905388, violated group size: 0.3579910732566234
# iteration: 495, error: 0.3445133535097091, fairness violation: 0.00445857534573995, violated group size: 0.40272716104991607
# iteration: 496, error: 0.34535247625325105, fairness violation: 0.004449586282542874, violated group size: 0.3579910732566234
# iteration: 497, error: 0.34618822224531004, fairness violation: 0.004440633392638365, violated group size: 0.40272716104991607
# iteration: 498, error: 0.3470206118277623, fairness violation: 0.004431716458115002, violated group size: 0.40272716104991607
# iteration: 499, error: 0.3478496651794232, fairness violation: 0.00442283526280816, violated group size: 0.3579910732566234

# %% [markdown]
# **3-d heatmaps**
#
# We now show to generate a 3d-heatmap of unfairness using the `generate_heatmap` method. The $X-Y$ axes in the plot represent the coefficients of the linear threshold function that defines a protected subgroup with respect to the first two sensitive attributes. Which $2$ attributes are considered sensitive can be overwritten with the `col_index` argument. The $Z$-axes is the $\gamma$-disparity (FP) of the corresponding subgroup defined by the linear threshold function. This is important because it allows us to (1) visualize convergence as the heatmap flattens and (2) brute force check the fairness in low-dimensions without relying on a heuristic auditor. See the [the rich subgroup fairness empirical paper](https://arxiv.org/abs/1808.08166) for a discussion of these plots. Note that in the below plot no group has a $\gamma$-disparity of greater than $.005$, which we would expect since the set of linear threshold functions on two attributes is a subset of the set of linear threshold functions on all protected attributes, and the final model is $\gamma$-fair.

# %%
# output heatmap (brute force)
# replace None with the relative path if you want to save the plot
fair_model.heatmapflag = True
fair_model.heatmap_path  = 'heatmap'
fair_model.generate_heatmap(data_set, dataset_yhat.labels)
Image(filename='{}.png'.format(fair_model.heatmap_path))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [3], line 5
#       3 fair_model.heatmapflag = True
#       4 fair_model.heatmap_path  = 'heatmap'
# ----> 5 fair_model.generate_heatmap(data_set, dataset_yhat.labels)
#       6 Image(filename='{}.png'.format(fair_model.heatmap_path))
#
# File ~/Documents/GitHub.nosync/Fair-Transparent-ML/AI360/aif360/algorithms/transformer.py:27, in addmetadata.<locals>.wrapper(self, *args, **kwargs)
#      25 @wraps(func)
#      26 def wrapper(self, *args, **kwargs):
# ---> 27     new_dataset = func(self, *args, **kwargs)
#      28     if isinstance(new_dataset, Dataset):
#      29         new_dataset.metadata = new_dataset.metadata.copy()
#
# File ~/Documents/GitHub.nosync/Fair-Transparent-ML/AI360/aif360/algorithms/inprocessing/gerryfair_classifier.py:253, in GerryFairClassifier.generate_heatmap(self, dataset, predictions, vmin, vmax, cols_index, eta)
#     251 # save heatmap every heatmap_iter iterations or the last iteration
#     252 X_prime_heat = X_prime.iloc[:, cols_index]
# --> 253 minmax = heatmap.heat_map(X, X_prime_heat, y, predictions, eta,
#     254                           self.heatmap_path, vmin, vmax)
#
# File ~/Documents/GitHub.nosync/Fair-Transparent-ML/AI360/aif360/algorithms/inprocessing/gerryfair/heatmap.py:82, in heat_map(X, X_prime, y, predictions, eta, plot_path, vmin, vmax)
#      80         attribute_1[i] = beta[0]
#      81         attribute_2[j] = beta[1]
# ---> 82         disparity[i, j] = calc_disp(predictions, X, y, X_prime, group)
#      84 X_plot, Y_plot = np.meshgrid(attribute_1, attribute_2)
#      86 ax.set_xlabel(columns[0] + ' coefficient')
#
# File ~/Documents/GitHub.nosync/Fair-Transparent-ML/AI360/aif360/algorithms/inprocessing/gerryfair/heatmap.py:39, in calc_disp(predictions, X, group_labels, X_prime, group)
#      27 def calc_disp(predictions, X, group_labels, X_prime, group):
#      28     """Return the fp disparity in a group g - helper function for heat_map.
#      29
#      30     Args:
#    (...)
#      37         :return: weighted disparity on the group g
#      38     """
# ---> 39     X_0 = pd.DataFrame(
#      40         [X_prime.iloc[u, :] for u, s in enumerate(group_labels) if s == 0])
#      41     group_0 = group.predict(X_0)
#      42     n = len(group_labels)
#
# File /opt/anaconda3/envs/fair-ML/lib/python3.10/site-packages/pandas/core/frame.py:721, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     716     if columns is not None:
#     717         # error: Argument 1 to "ensure_index" has incompatible type
#     718         # "Collection[Any]"; expected "Union[Union[Union[ExtensionArray,
#     719         # ndarray], Index, Series], Sequence[Any]]"
#     720         columns = ensure_index(columns)  # type: ignore[arg-type]
# --> 721     arrays, columns, index = nested_data_to_arrays(
#     722         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     723         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     724         data,
#     725         columns,
#     726         index,  # type: ignore[arg-type]
#     727         dtype,
#     728     )
#     729     mgr = arrays_to_mgr(
#     730         arrays,
#     731         columns,
#    (...)
#     734         typ=manager,
#     735     )
#     736 else:
#
# File /opt/anaconda3/envs/fair-ML/lib/python3.10/site-packages/pandas/core/internals/construction.py:519, in nested_data_to_arrays(data, columns, index, dtype)
#     516 if is_named_tuple(data[0]) and columns is None:
#     517     columns = ensure_index(data[0]._fields)
# --> 519 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     520 columns = ensure_index(columns)
#     522 if index is None:
#
# File /opt/anaconda3/envs/fair-ML/lib/python3.10/site-packages/pandas/core/internals/construction.py:877, in to_arrays(data, columns, dtype)
#     875     arr, columns = _list_of_dict_to_arrays(data, columns)
#     876 elif isinstance(data[0], ABCSeries):
# --> 877     arr, columns = _list_of_series_to_arrays(data, columns)
#     878 else:
#     879     # last ditch effort
#     880     data = [tuple(x) for x in data]
#
# File /opt/anaconda3/envs/fair-ML/lib/python3.10/site-packages/pandas/core/internals/construction.py:923, in _list_of_series_to_arrays(data, columns)
#     920         indexer = indexer_cache[id(index)] = index.get_indexer(columns)
#     922     values = extract_array(s, extract_numpy=True)
# --> 923     aligned_values.append(algorithms.take_nd(values, indexer))
#     925 # error: Argument 1 to "vstack" has incompatible type "List[ExtensionArray]";
#     926 # expected "Sequence[Union[Union[int, float, complex, str, bytes, generic],
#     927 # Sequence[Union[int, float, complex, str, bytes, generic]],
#     928 # Sequence[Sequence[Any]], _SupportsArray]]"
#     929 content = np.vstack(aligned_values)  # type: ignore[arg-type]
#
# File /opt/anaconda3/envs/fair-ML/lib/python3.10/site-packages/pandas/core/array_algos/take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File /opt/anaconda3/envs/fair-ML/lib/python3.10/site-packages/pandas/core/array_algos/take.py:134, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     131 else:
#     132     indexer = ensure_platform_int(indexer)
# --> 134 dtype, fill_value, mask_info = _take_preprocess_indexer_and_fill_value(
#     135     arr, indexer, fill_value, allow_fill
#     136 )
#     138 flip_order = False
#     139 if arr.ndim == 2 and arr.flags.f_contiguous:
#
# File /opt/anaconda3/envs/fair-ML/lib/python3.10/site-packages/pandas/core/array_algos/take.py:554, in _take_preprocess_indexer_and_fill_value(arr, indexer, fill_value, allow_fill, mask)
#     550             v = col_idx[j]
#     551             out[i, j] = arr[u_, v]
# --> 554 def _take_preprocess_indexer_and_fill_value(
#     555     arr: np.ndarray,
#     556     indexer: npt.NDArray[np.intp],
#     557     fill_value,
#     558     allow_fill: bool,
#     559     mask: npt.NDArray[np.bool_] | None = None,
#     560 ):
#     561     mask_info: tuple[np.ndarray | None, bool] | None = None
#     563     if not allow_fill:
#
# KeyboardInterrupt:

# %% [markdown]
# **black-box auditing**
#
# We now show to audit any black box classifier with respect to rich subgroup fairness under either FP or FN rate. Note the below auditing procedure would work for any set of (soft) predictions $\hat{y}$, and need make no assumptions about the structure of the predictor. We note that as expected the disparity of the group found is the same as the disparity printed out in the last iteration of the `fit` method.

# %%
gerry_metric = BinaryLabelDatasetMetric(data_set)
gamma_disparity = gerry_metric.rich_subgroup(array_to_tuple(dataset_yhat.labels), 'FP')
print(gamma_disparity)
# Out:
# 0.004955178356713431

# %% [markdown]
# **pareto curves**
#
# The `FairFictPlay` algorithm implemented in the `fit` method converges given access to perfect oracles for solving cost-sensitive classification (CSC) problems. A cost-sensitive classification problem over a hypothesis class $\mathcal{H}$ is $$\min_{h}\sum_{i = 1}^{n}(1-h(x_i))c_0 + h(x_i)c_1$$
# By default in this package, and in the companion [empirical](https://arxiv.org/abs/1808.08166) and [theory](https://arxiv.org/pdf/1711.05144.pdf) papers, the hypothesis class of the learner and the of the subgroups are hyperplanes. The corresponding heuristic oracle for solving the CSC problem first forms two regression problems $(x_i, c_0)$ and $(x_i, c_1)$. Then in the case of hyperplanes, trains two regressions $r_i: \mathcal{X} \to R$ which predict the costs of classifying a given point $x$ $0,1$ respectively. Finally the binary classifier output by the oracle is defined as $\hat{r}(x) = \arg\min_{j \in \{0,1\}}r_j(x)$. But of course if we are interesting in different hypothesis classes for the learner, we simply need different regressors. In this package in addition to linear regression, we've added support for regression trees, kernelized ridge regression, and support vector regression. Below we trace out Pareto curves of $\gamma$-disparity vs. error for each of these different heuristic oracles.

# %%
# set to 50 iterations for fast running of notebook - set >= 1000 when running real experiments
pareto_iters = 50
def multiple_classifiers_pareto(dataset, gamma_list=[0.002, 0.005, 0.01, 0.02, 0.05, 0.1], save_results=False, iters=pareto_iters):

    ln_predictor = linear_model.LinearRegression()
    svm_predictor = svm.LinearSVR()
    tree_predictor = tree.DecisionTreeRegressor(max_depth=3)
    kernel_predictor = KernelRidge(alpha=1.0, gamma=1.0, kernel='rbf')
    predictor_dict = {'Linear': {'predictor': ln_predictor, 'iters': iters},
                      'SVR': {'predictor': svm_predictor, 'iters': iters},
                      'Tree': {'predictor': tree_predictor, 'iters': iters},
                      'Kernel': {'predictor': kernel_predictor, 'iters': iters}}

    results_dict = {}

    for pred in predictor_dict:
        print('Curr Predictor: {}'.format(pred))
        predictor = predictor_dict[pred]['predictor']
        max_iters = predictor_dict[pred]['iters']
        fair_clf = GerryFairClassifier(C=100, printflag=True, gamma=1, predictor=predictor, max_iters=max_iters)
        fair_clf.printflag = False
        fair_clf.max_iters=max_iters
        errors, fp_violations, fn_violations = fair_clf.pareto(dataset, gamma_list)
        results_dict[pred] = {'errors': errors, 'fp_violations': fp_violations, 'fn_violations': fn_violations}
        plt.plot(errors, fp_violations, label=pred)

    if save_results:
        pickle.dump(results_dict, open('results_dict_' + str(gamma_list) + '_gammas' + str(gamma_list) + '.pkl', 'wb'))

    plt.xlabel('Error')
    plt.ylabel('Unfairness')
    plt.legend()
    plt.title('Error vs. Unfairness\n(Adult Dataset)')
    plt.savefig('gerryfair_pareto.png')
    plt.close()
multiple_classifiers_pareto(data_set)
Image(filename='gerryfair_pareto.png')
# Out:
# Curr Predictor: Linear
# Curr Predictor: SVR

# %% [markdown]
# A natural question one might ask is, suppose we fix a statistical fairness definition for rich subgroup fairness like equality of false positive rates, `FP`. Does learning a classifier that is fair with respect to `FP` increase or decrease fairness with respect to false negative rates `FN`? One could see this relationship going in either direction - and indeed we submit that it is dataset dependent. In some cases, if enforcing `FP` fairness pushes the classifier towards the constant classifier, then it will also satisify `FN` rate fairness, since the constant classifier is perfectly fair. However, if the hypothesis class is sufficiently rich, then one would expect that ceteris paribus since we are optimizing for error in addition to `FP` rate fairness, the algorithm would increase `FN` rate unfairness in order to decrease error. Below we trace the FN vs. FP rate tradeoff across a range of input $\gamma$, where the classifier is optimized only for `FP` rate fairness.

# %%
def fp_vs_fn(dataset, gamma_list, iters):
    fp_auditor = Auditor(dataset, 'FP')
    fn_auditor = Auditor(dataset, 'FN')
    fp_violations = []
    fn_violations = []
    for g in gamma_list:
        print('gamma: {} '.format(g), end =" ")
        fair_model = GerryFairClassifier(C=100, printflag=False, gamma=g, max_iters=iters)
        fair_model.gamma=g
        fair_model.fit(dataset)
        predictions = array_to_tuple((fair_model.predict(dataset)).labels)
        _, fp_diff = fp_auditor.audit(predictions)
        _, fn_diff = fn_auditor.audit(predictions)
        fp_violations.append(fp_diff)
        fn_violations.append(fn_diff)

    plt.plot(fp_violations, fn_violations, label='adult')
    plt.xlabel('False Positive Disparity')
    plt.ylabel('False Negative Disparity')
    plt.legend()
    plt.title('FP vs FN Unfairness')
    plt.savefig('gerryfair_fp_fn.png')
    plt.close()

gamma_list = [0.001, 0.002, 0.003, 0.004, 0.005, 0.0075, 0.01, 0.02, 0.03, 0.05]
fp_vs_fn(data_set, gamma_list, pareto_iters)
Image(filename='gerryfair_fp_fn.png')
# Out:
# gamma: 0.001  gamma: 0.002  gamma: 0.003  gamma: 0.004  gamma: 0.005  gamma: 0.0075  gamma: 0.01  gamma: 0.02  gamma: 0.03  gamma: 0.05
